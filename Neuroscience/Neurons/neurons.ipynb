# %% [markdown]
# # Neuron Models

# %% [markdown]
# ## Perceptron

# %% [markdown]
# ## Rate Neuron

# %% [markdown]
# ## Leaky Rate Neuron

# %% [markdown]
# ## Spiking Neuron
# Implementation of Leaky Integrate and Fire Neuron
